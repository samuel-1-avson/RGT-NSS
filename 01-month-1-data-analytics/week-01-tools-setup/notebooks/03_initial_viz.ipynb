# %% [markdown]
# # Week 1: Initial Visualizations
#
# Creating key visualizations to understand patterns in the Telco Customer Churn dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# Load data
df = pd.read_csv('../data/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# Clean TotalCharges
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

print(f"Data loaded: {df.shape}")

# %% [markdown]
# ## 1. Monthly Charges by Churn

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Churn', y='MonthlyCharges', palette='Set2')
plt.title('Monthly Charges by Churn Status', fontsize=14)
plt.xlabel('Churn')
plt.ylabel('Monthly Charges ($)')
plt.tight_layout()
plt.savefig('../outputs/monthly_charges_by_churn.png', dpi=300, bbox_inches='tight')
plt.show()

# Print statistics
print("\nMonthly Charges by Churn:")
print(df.groupby('Churn')['MonthlyCharges'].describe().round(2))

# %% [markdown]
# ## 2. Tenure Distribution by Churn

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='tenure', hue='Churn', bins=30, kde=True, palette='Set2')
plt.title('Tenure Distribution by Churn Status', fontsize=14)
plt.xlabel('Tenure (months)')
plt.ylabel('Count')
plt.tight_layout()
plt.savefig('../outputs/tenure_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# Print statistics
print("\nTenure by Churn:")
print(df.groupby('Churn')['tenure'].describe().round(2))

# %% [markdown]
# ## 3. Churn by Contract Type

# %%
plt.figure(figsize=(10, 6))
contract_churn = pd.crosstab(df['Contract'], df['Churn'], normalize='index') * 100
contract_churn.plot(kind='bar', color=['steelblue', 'coral'])
plt.title('Churn Rate by Contract Type', fontsize=14)
plt.xlabel('Contract Type')
plt.ylabel('Percentage')
plt.legend(title='Churn')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('../outputs/churn_by_contract.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nChurn Rate by Contract:")
print(contract_churn.round(1))

# %% [markdown]
# ## 4. Correlation Heatmap (Numeric Variables)

# %%
plt.figure(figsize=(10, 8))

# Select numeric columns
numeric_df = df[['tenure', 'MonthlyCharges', 'TotalCharges', 'SeniorCitizen']].copy()

# Add churn as numeric
numeric_df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# Calculate correlation
corr = numeric_df.corr()

# Plot heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0, 
            square=True, fmt='.2f', cbar_kws={'shrink': 0.8})
plt.title('Correlation Heatmap', fontsize=14)
plt.tight_layout()
plt.savefig('../outputs/correlation_heatmap.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nCorrelations with Churn:")
print(corr['Churn'].sort_values(ascending=False).round(3))

# %% [markdown]
# ## 5. Churn by Internet Service

# %%
plt.figure(figsize=(10, 6))
internet_churn = pd.crosstab(df['InternetService'], df['Churn'], normalize='index') * 100
internet_churn.plot(kind='bar', color=['steelblue', 'coral'])
plt.title('Churn Rate by Internet Service Type', fontsize=14)
plt.xlabel('Internet Service')
plt.ylabel('Percentage')
plt.legend(title='Churn')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('../outputs/churn_by_internet.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nChurn Rate by Internet Service:")
print(internet_churn.round(1))

# %% [markdown]
# ## 6. Summary
#
# **Key Insights from Visualizations:**
#
# 1. **Monthly Charges**: Customers who churn tend to have higher monthly charges
# 2. **Tenure**: New customers (low tenure) are more likely to churn
# 3. **Contract Type**: Month-to-month contracts have much higher churn rates
# 4. **Internet Service**: Fiber optic customers have higher churn rates
# 5. **Correlations**: Tenure is negatively correlated with churn
